# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
base_color = sb.color_palette()[0]

# %%
df = pd.read_csv('Untitled spreadsheet - Sheet1.csv')

# %%
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1      Q1 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0        Sex       Year  Deaths       Rate        LCI        UCI         NaN
# 1    Persons       2019   1,240       10.3        9.7       10.8         NaN
# 2        NaN       2018   1,143        9.5        9.0       10.1         NaN
# 3        NaN       2017   1,035        8.7        8.2        9.2         NaN
# 4        NaN       2016   1,082        9.0        8.5        9.6         NaN
#
#        Q2 Unnamed: 8 Unnamed: 9  ... Unnamed: 11      Q3 Unnamed: 13  \
# 0  Deaths       Rate        LCI  ...         NaN  Deaths        Rate
# 1   1,271       10.4        9.8  ...         NaN   1,324        10.7
# 2   1,253       10.3        9.7  ...         NaN   1,301        10.6
# 3   1,118        9.2        8.7  ...         NaN   1,168         9.6
# 4   1,147        9.5        9.0  ...         NaN   1,139         9.4
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16      Q4 Unnamed: 18 Unnamed: 19  \
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
q1 = df[['Unnamed: 1', 'Q1', 'Unnamed: 3']]

# %%
q2 = df[['Unnamed: 1', 'Q2', 'Unnamed: 8']]

# %%
q3 = df[['Unnamed: 1', 'Q3', 'Unnamed: 13']]

# %%
q4 = df[['Unnamed: 1', 'Q4', 'Unnamed: 18']]

# %%
q4
# Out:
#    Unnamed: 1      Q4 Unnamed: 18
# 0        Year  Deaths        Rate
# 1        2019   1,413        11.3
# 2        2018   1,324        10.7
# 3        2017   1,130         9.2
# 4        2016   1,207         9.9
# 5        2015   1,260        10.4
# 6        2014   1,190         9.9
# 7        2013   1,273        10.7
# 8        2012   1,222        10.3
# 9        2011   1,158         9.9
# 10       2010   1,094         9.4
# 11       2009   1,169        10.1
# 12       2008   1,169        10.2
# 13       2007   1,066         9.3
# 14       2006   1,103         9.7
# 15       2005   1,143        10.2
# 16       2004   1,164        10.5
# 17       2003   1,214        11.0
# 18       2002   1,140        10.3
# 19       2001   1,252        11.4

# %%
q1.rename(columns={"Unnamed: 1": "Year", "Q1": "Deaths", "Unnamed: 3": "Rate"}, inplace=True);
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
q2.rename(columns={"Unnamed: 1": "Year", "Q2": "Deaths", "Unnamed: 8": "Rate"}, inplace=True);

# %%
q3.rename(columns={"Unnamed: 1": "Year", "Q3": "Deaths", "Unnamed: 13": "Rate"}, inplace=True);

# %%
q4.rename(columns={"Unnamed: 1": "Year", "Q4": "Deaths", "Unnamed: 18": "Rate"}, inplace=True);

# %%
q1.drop(0, inplace=True);
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
q2.drop(0, inplace=True);

# %%
q3.drop(0, inplace=True);

# %%
q4.drop(0, inplace=True);

# %%
q1.rename(index={"Unnamed: 1": "Year", "Q4": "Deaths", "Unnamed: 18": "Rate"}, inplace=True);

# %%
for i, row in q1.iterrows():
    q1.loc[i, "Year"] = q1.loc[i, "Year"], 'Q1'
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i, row in q2.iterrows():
    q2.loc[i, "Year"] = q2.loc[i, "Year"], 'Q2'
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i, row in q3.iterrows():
    q3.loc[i, "Year"] = q3.loc[i, "Year"], 'Q3'
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i, row in q4.iterrows():
    q4.loc[i, "Year"] = q4.loc[i, "Year"], 'Q4'
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = pd.concat([q1, q2, q3, q4], axis=0)

# %%
df.sort_values('Year', inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     index        Year Deaths  Rate
# 0      19  (2001, Q1)  1,090  10.2
# 1      19  (2001, Q2)  1,065   9.9
# 2      19  (2001, Q3)  1,150  10.6
# 3      19  (2001, Q4)  1,252  11.4
# 4      18  (2002, Q1)  1,029   9.6
# ..    ...         ...    ...   ...
# 71      2  (2018, Q4)  1,324  10.7
# 72      1  (2019, Q1)  1,240  10.3
# 73      1  (2019, Q2)  1,271  10.4
# 74      1  (2019, Q3)  1,324  10.7
# 75      1  (2019, Q4)  1,413  11.3
#
# [76 rows x 4 columns]

# %%
df.drop(columns=['index'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    76 non-null     object
#  1   Deaths  76 non-null     object
#  2   Rate    76 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
df
# Out:
#           Year Deaths  Rate
# 0   (2001, Q1)  1,090  10.2
# 1   (2001, Q2)  1,065   9.9
# 2   (2001, Q3)  1,150  10.6
# 3   (2001, Q4)  1,252  11.4
# 4   (2002, Q1)  1,029   9.6
# ..         ...    ...   ...
# 71  (2018, Q4)  1,324  10.7
# 72  (2019, Q1)  1,240  10.3
# 73  (2019, Q2)  1,271  10.4
# 74  (2019, Q3)  1,324  10.7
# 75  (2019, Q4)  1,413  11.3
#
# [76 rows x 3 columns]

# %% [markdown]
# df['Year'] = df['Year'].str.strip('()').astype(int)

# %%
df['Deaths'] = df['Deaths'].str.replace(',','')

# %%
df['Deaths'] = pd.to_numeric(df['Deaths'])

# %%
df['Rate'] = pd.to_numeric(df['Rate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    76 non-null     object
#  1   Deaths  76 non-null     int64
#  2   Rate    76 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.9+ KB

# %% [markdown]
# ### Suicide

# %%
df2 = pd.read_csv('age.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  19 non-null     float64
#  1   Unnamed: 1  323 non-null    object
#  2   Q1          323 non-null    int64
#  3   Q2          323 non-null    int64
#  4   Q3          323 non-null    int64
#  5   Q4          323 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 15.3+ KB

# %%
df2.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Q1   Q2   Q3   Q4
# 0      2019.0      10-14    1    4    4    1
# 1         NaN      15-19   37   56   37   44
# 2         NaN      20-24   92   75   93  114
# 3         NaN      25-29  105  121  100  136
# 4         NaN      30-34  121  108  127  122

# %%
years = []
for i, row in df2.iterrows():
    if pd.notnull(df2.loc[i, "Unnamed: 0"]):
        years.append(df2.loc[i, "Unnamed: 0"])
        print([i])
# Out:
# [0]
# [17]
# [34]
# [51]
# [68]
# [85]
# [102]
# [119]
# [136]
# [153]
# [170]
# [187]
# [204]
# [221]
# [238]
# [255]
# [272]
# [289]
# [306]

# %%
df2.iloc[17:33]
# Out:
#     Unnamed: 0 Unnamed: 1   Q1   Q2   Q3   Q4
# 17      2018.0      10-14    3    1    3    3
# 18         NaN      15-19   41   48   48   41
# 19         NaN      20-24   83   94   95   86
# 20         NaN      25-29   74   93   96  128
# 21         NaN      30-34   90  107  119  127
# 22         NaN      35-39  101  102  103  114
# 23         NaN      40-44   97  121  114  124
# 24         NaN      45-49  168  161  165  154
# 25         NaN      50-54  128  117  155  155
# 26         NaN      55-59   90  107  103   98
# 27         NaN      60-64   76   85   78   74
# 28         NaN      65-69   49   50   69   60
# 29         NaN      70-74   39   52   46   49
# 30         NaN      75-79   38   38   34   43
# 31         NaN      80-84   23   39   35   40
# 32         NaN      85-89   23   23   27   22

# %%
def mergeframes(df, a, b):
    dfm = df.iloc[a:b]
    df = pd.merge(df, dfm,
              on='Unnamed: 1', how='left')
    return df

# %%
mergeframes(df2, 0, 16)
# Out:
#      Unnamed: 0_x Unnamed: 1  Q1_x  Q2_x  Q3_x  Q4_x  Unnamed: 0_y   Q1_y  \
# 0          2019.0      10-14     1     4     4     1        2019.0    1.0
# 1             NaN      15-19    37    56    37    44           NaN   37.0
# 2             NaN      20-24    92    75    93   114           NaN   92.0
# 3             NaN      25-29   105   121   100   136           NaN  105.0
# 4             NaN      30-34   121   108   127   122           NaN  121.0
# ..            ...        ...   ...   ...   ...   ...           ...    ...
# 318           NaN      70-74    30    48    52    51           NaN   53.0
# 319           NaN      75-79    46    46    37    38           NaN   33.0
# 320           NaN      80-84    26    23    32    29           NaN   25.0
# 321           NaN      85-89    20    20    16    25           NaN   23.0
# 322           NaN        90+     8     7    15    11           NaN    NaN
#
#       Q2_y   Q3_y   Q4_y
# 0      4.0    4.0    1.0
# 1     56.0   37.0   44.0
# ...

# %%
mergeframes(df2, 17, 33);

# %%
mergeframes(df2, 34, 50)
# Out:
#      Unnamed: 0_x Unnamed: 1  Q1_x  Q2_x  Q3_x  Q4_x  Unnamed: 0_y  Q1_y  \
# 0          2019.0      10-14     1     4     4     1        2017.0   1.0
# 1             NaN      15-19    37    56    37    44           NaN  33.0
# 2             NaN      20-24    92    75    93   114           NaN  57.0
# 3             NaN      25-29   105   121   100   136           NaN  87.0
# 4             NaN      30-34   121   108   127   122           NaN  71.0
# ..            ...        ...   ...   ...   ...   ...           ...   ...
# 318           NaN      70-74    30    48    52    51           NaN  41.0
# 319           NaN      75-79    46    46    37    38           NaN  36.0
# 320           NaN      80-84    26    23    32    29           NaN  28.0
# 321           NaN      85-89    20    20    16    25           NaN  16.0
# 322           NaN        90+     8     7    15    11           NaN   NaN
#
#       Q2_y   Q3_y   Q4_y
# 0      2.0    3.0    4.0
# 1     38.0   49.0   35.0
# ...

# %% [markdown]
# ### GDP Data

# %%
gdp = pd.read_excel('WID_Data_08112020-191426.xlsx')

# %%
gdp
# Out:
#     Percentile  Year  \
# 0       p0p100  1855
# 1       p0p100  1856
# 2       p0p100  1857
# 3       p0p100  1858
# 4       p0p100  1859
# ..         ...   ...
# 160     p0p100  2015
# 161     p0p100  2016
# 162     p0p100  2017
# 163     p0p100  2018
# 164     p0p100  2019
#
#      agdpro_z_GB\nGross domestic product\nP0-100 | average income or wealth | Euro € | ppp | constant (2019)\nUnited Kingdom
# 0                                            4680.5639
# 1                                            4837.0885
# 2                                            5097.9276
# 3                                            5313.2538
# 4                                            5757.7162
# ..                                                 ...
# 160                                         42465.8500
# 161                                         43006.1556
# 162                                         43533.6924
# 163                                         43844.8560
# ...

# %%
gdp.drop('Percentile', axis=1, inplace=True)

# %%
gdp.rename(columns={'agdpro_z_GB\nGross domestic product\nP0-100 | average income or wealth | Euro € | ppp | constant (2019)\nUnited Kingdom': 'GDP'}, inplace=True)

# %%
gdp
# Out:
#      Year         GDP
# 0    1855   4680.5639
# 1    1856   4837.0885
# 2    1857   5097.9276
# 3    1858   5313.2538
# 4    1859   5757.7162
# ..    ...         ...
# 160  2015  42465.8500
# 161  2016  43006.1556
# 162  2017  43533.6924
# 163  2018  43844.8560
# 164  2019  44174.7512
#
# [165 rows x 2 columns]

# %%
ons_gdp = pd.read_excel('series-061120.xls')

# %%
ons_gdp
# Out:
#                  Title  \
# 0                 CDID
# 1    Source dataset ID
# 2              PreUnit
# 3                 Unit
# 4         Release date
# ..                 ...
# 263            2019 Q2
# 264            2019 Q3
# 265            2019 Q4
# 266            2020 Q1
# 267            2020 Q2
#
#     Gross Domestic Product: Quarter on Quarter growth: CVM SA %
# 0                                                 IHYQ
# 1                                                  QNA
# 2                                                  NaN
# 3                                                    %
# 4                                           30-09-2020
# ..                                                 ...
# 263                                                  0
# 264                                                0.3
# 265                                                0.1
# 266                                               -2.5
# 267                                              -19.8
#
# ...

# %%
ons_gdp.drop([0,1,2,3,4,5,6], inplace=True)

# %%
ons_gdp.rename(columns={'Gross Domestic Product: Quarter on Quarter growth: CVM SA %': 'GDP: Quarter on Quarter growth'}, inplace=True)

# %%
gdp['GDP: Year on Year Growth'] = gdp.GDP.pct_change()

# %%
gdp.drop(0, inplace=True)

# %%
gdp.drop('GDP', axis=1, inplace=True)

# %%
gdp
# Out:
#      Year  GDP: Year on Year Growth
# 1    1856                  0.033441
# 2    1857                  0.053925
# 3    1858                  0.042238
# 4    1859                  0.083652
# 5    1860                 -0.040869
# ..    ...                       ...
# 160  2015                  0.013689
# 161  2016                  0.012723
# 162  2017                  0.012267
# 163  2018                  0.007148
# 164  2019                  0.007524
#
# [164 rows x 2 columns]

# %% [markdown]
# ### Debt Data

# %%
debt = pd.read_csv('Figure_2__Debt_expressed_as_a_percentage_of_GDP_has_reached_levels_last_seen_in_the_early_1960s.csv')

# %%
debt.drop([0,1,2,3,4,5,6,30,31,32,33,34,35,36], inplace=True)

# %%
debt.rename(columns={'Figure 2: Debt expressed as a percentage of GDP has reached levels last seen in the early 1960s': 'Year',
                    'Unnamed: 1': 'debt/GDP'}, inplace=True)

# %% [markdown]
# ### Borrowing Data

# %%
borrow = pd.read_excel('77e15c82.xls')

# %%
borrow.drop([0,1], inplace=True)

# %%
borrow.drop(['Unnamed: 1', 'Unnamed: 2','Unnamed: 3', 'Unnamed: 5', 'Unnamed: 5', 'Unnamed: 6'], axis=1, inplace=True)

# %%
borrow.rename(columns={'Unnamed: 4': borrow['Unnamed: 4'][2]}, inplace=True);

# %%
borrow
# Out:
#    Figure 8: Borrowing in the latest financial year was around one-third (35.8%) of the amount borrowed in the financial year ending March 2010  \
# 2                                                Year
# 3                                            1993/94
# 4                                            1994/95
# 5                                            1995/96
# 6                                            1996/97
# 7                                            1997/98
# 8                                            1998/99
# 9                                            1999/00
# 10                                           2000/01
# 11                                           2001/02
# 12                                           2002/03
# 13                                           2003/04
# 14                                           2004/05
# 15                                           2005/06
# 16                                           2006/07
# ...

# %%
borrow.rename(columns={'Figure 8: Borrowing in the latest financial year was around one-third (35.8%) of the amount borrowed in the financial year ending March 2010': 'Year'}, inplace=True)

# %%
borrow.columns.tolist()
# Out:
# ['Year', 'Public sector net borrowing as a percentage of GDP ']

# %%
borrow
# Out:
#                                                  Year  \
# 2                                                Year
# 3                                            1993/94
# 4                                            1994/95
# 5                                            1995/96
# 6                                            1996/97
# 7                                            1997/98
# 8                                            1998/99
# 9                                            1999/00
# 10                                           2000/01
# 11                                           2001/02
# 12                                           2002/03
# 13                                           2003/04
# 14                                           2004/05
# 15                                           2005/06
# 16                                           2006/07
# 17                                           2007/08
# 18                                           2008/09
# ...

# %%
borrow.rename(columns = {'Public sector net borrowing as a percentage of GDP ': 'Debt/GDP'}, inplace=True);

# %%
borrow.drop([2,30,31,32,33,34,35,36], inplace=True)

# %%
borrow['Debt/GDP'] = pd.to_numeric(borrow['Debt/GDP'])

# %%
plt.figure(figsize=(75, 30))
sb.set(font_scale=4)
sb.lineplot(data=borrow, x="Year", y='Debt/GDP')
plt.xticks(rotation=45);

# %% [markdown]
# ### Income Inequaliy Data

# %%
unequal = pd.read_excel('WID_Data_08112020-204601.xlsx')

# %%
bottom = unequal[unequal['Percentile']=='p90p100']

# %%
bottom.drop('Percentile', axis=1, inplace=True)
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
bottom.rename(columns={'sdiinc_z_GB\nPost-tax national income\nTop 10% | share\nUnited Kingdom': 'Post-tax national income'}, inplace=True)
# Out:
# /Users/louisthomasdods/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
top = unequal[unequal['Percentile']=='p0p50']

# %%
top.drop('Percentile', axis=1, inplace=True)

# %%
top.rename(columns={'sdiinc_z_GB\nPost-tax national income\nTop 10% | share\nUnited Kingdom': 'Post-tax national income'}, inplace=True)

# %%
plt.figure(figsize=(75, 30))
sb.set(font_scale=4)
plt.xticks(rotation=45)
sb.lineplot(data=top, x="Year", y="Post-tax national income");

# %%
plt.figure(figsize=(75, 30))
sb.set(font_scale=4)
plt.xticks(rotation=45)
sb.lineplot(data=bottom, x="Year", y="Post-tax national income");

# %% [markdown]
# ### Employment Data

# %%
employ = pd.read_excel('WID_Data_08112020-210932.xlsx')

# %%
employ.drop('Percentile', axis=1, inplace=True)

# %%
employ.rename(columns={'npopem_999_i_GB\nEmployed population\nTotal population | units | all ages | individual\nUnited Kingdom':'Employed population'}, inplace=True)

# %%
employ
# Out:
#      Year  Employed population
# 0    1855             11760000
# 1    1856             11890000
# 2    1857             11910000
# 3    1858             11610000
# 4    1859             12280000
# ..    ...                  ...
# 154  2009             29154250
# 155  2010             29227000
# 156  2011             29374500
# 157  2012             29694750
# 158  2013             30040750
#
# [159 rows x 2 columns]

# %%
pop = pd.read_excel('WID_Data_08112020-211634.xlsx')

# %%
pop
# Out:
#     Percentile  Year  \
# 0         pall  1855
# 1         pall  1856
# 2         pall  1857
# 3         pall  1858
# 4         pall  1859
# ..         ...   ...
# 160       pall  2015
# 161       pall  2016
# 162       pall  2017
# 163       pall  2018
# 164       pall  2019
#
#      npopul_999_i_GB\nPopulation\nTotal population | units | all ages | individual\nUnited Kingdom
# 0                                             27822000
# 1                                             28011000
# 2                                             28187000
# 3                                             28390000
# 4                                             28591000
# ..                                                 ...
# 160                                           64970292
# 161                                           65402176
# 162                                           65825884
# 163                                           66234508
# ...

# %%
pop.drop('Percentile', axis=1, inplace=True)

# %%
pop.rename(columns={'npopul_999_i_GB\nPopulation\nTotal population | units | all ages | individual\nUnited Kingdom': 'Population'}, inplace=True)

# %%
employ = pd.merge(employ,  pop, on='Year', how='left')

# %%
employ
# Out:
#      Year  Employed population  Population
# 0    1855             11760000    27822000
# 1    1856             11890000    28011000
# 2    1857             11910000    28187000
# 3    1858             11610000    28390000
# 4    1859             12280000    28591000
# ..    ...                  ...         ...
# 154  2009             29154250    62260000
# 155  2010             29227000    62759000
# 156  2011             29374500    63285000
# 157  2012             29694750    63705000
# 158  2013             30040750    64106000
#
# [159 rows x 3 columns]

# %%
employ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 0 to 158
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 159 non-null    int64
#  1   Employed population  159 non-null    int64
#  2   Population           159 non-null    int64
# dtypes: int64(3)
# memory usage: 5.0 KB

# %%
employ['% employed'] = employ['Employed population']/employ['Population']

# %%
employ
# Out:
#      Year  Employed population  Population  % employed
# 0    1855             11760000    27822000    0.422687
# 1    1856             11890000    28011000    0.424476
# 2    1857             11910000    28187000    0.422535
# 3    1858             11610000    28390000    0.408947
# 4    1859             12280000    28591000    0.429506
# ..    ...                  ...         ...         ...
# 154  2009             29154250    62260000    0.468266
# 155  2010             29227000    62759000    0.465702
# 156  2011             29374500    63285000    0.464162
# 157  2012             29694750    63705000    0.466129
# 158  2013             30040750    64106000    0.468611
#
# [159 rows x 4 columns]

# %%
plt.figure(figsize=(75, 30))
sb.set(font_scale=4)
plt.xticks(rotation=45)
sb.lineplot(data=employ, x="Year", y="% employed");
